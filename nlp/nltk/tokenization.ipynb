# %% [markdown]
# # Understanding tokenization

# %%
corpus = """
Hi welcome to my house.
Please don't go without doing dinner.
"""

# %%
print(corpus)
# Out:
# Hi welcome to my house.
# Please don't go without doing dinner.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize, wordpunct_tokenize, TreebankWordTokenizer

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\aksha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
documents = sent_tokenize(corpus)
documents
# Out:
# ['\nHi welcome to my house.', "Please don't go without doing dinner."]

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hi welcome to my house.
# Please don't go without doing dinner.

# %%
word_tokenize(corpus)
# Out:
# ['Hi',
#  'welcome',
#  'to',
#  'my',
#  'house',
#  '.',
#  'Please',
#  'do',
#  "n't",
#  'go',
#  'without',
#  'doing',
#  'dinner',
#  '.']

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hi',
#  'welcome',
#  'to',
#  'my',
#  'house',
#  '.',
#  'Please',
#  'don',
#  "'",
#  't',
#  'go',
#  'without',
#  'doing',
#  'dinner',
#  '.']

# %%
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hi',
#  'welcome',
#  'to',
#  'my',
#  'house.',
#  'Please',
#  'do',
#  "n't",
#  'go',
#  'without',
#  'doing',
#  'dinner',
#  '.']
