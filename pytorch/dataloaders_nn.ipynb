# %% [markdown]
# Understanding Neural Network, Layers, Loss and Optimisers in Pytorch

# %%
import torch
from torch import nn, optim

# %%
w = torch.tensor(0.0, requires_grad=True)

# %%
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.Linear = nn.Linear(1, 1)   

    def forward(self, x):
        return self.Linear(x)
    
x = torch.tensor([[1.], [2.], [3.], [4.]])
y = torch.tensor([[2.], [4.], [6.], [8.]])

model = MyModel()

loss_fn = nn.MSELoss()

optimiser = optim.Adam(model.parameters(), lr=0.1)

for epoch in range(10):
    optimiser.zero_grad()
    y_pred = model(x)
    loss = loss_fn(y_pred, y)
    loss.backward()
    optimiser.step()

    print(f"Epoch {epoch + 1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 1, Loss: 11.9137
# Epoch 2, Loss: 9.5259
# Epoch 3, Loss: 7.4171
# Epoch 4, Loss: 5.5903
# Epoch 5, Loss: 4.0458
# Epoch 6, Loss: 2.7798
# Epoch 7, Loss: 1.7840
# Epoch 8, Loss: 1.0448
# Epoch 9, Loss: 0.5418
# Epoch 10, Loss: 0.2484

# %% [markdown]
# Saving a model in pytorch

# %%
torch.save(model.state_dict(), "linear_model.pt")
